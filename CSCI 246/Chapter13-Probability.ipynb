# %% [markdown]
# ## Madison Austin
# ## 10/14/25
# ## CSCI 246
# ## this assignment we will use some code (for calculations) to figure out the probabilities of the following questions related to chapter 13

# %% [markdown]
# ### Question 13.2.2
# If you roll two dice, what is the probability that the sum of the points is greater than 7? show your calculations and explain your reasoning. <br>
# ### Answer
# there is 6 sides so rolled twice so it would be $6 x 6 = 36$, our outcome with > 7, sums 8-12 there are 15 outcomes
# $p = 6/32 = 0.4166667$

# %% [markdown]
# ### Question 13.2.4
# If you toss a coin 5 times, what is the probability of getting tails at least 4 times?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# best outcomes $C(5,4) + C(5,5)= 5 + 1 = 6$ total outcomes $2^5 = 32$
# $p = 6/32 = 0.1875 $

# %% [markdown]
# ### Question 13.2.6
# What is the probability that a randomly selected number chosen from the first 50 positive integers is divisible by 3?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# count $50/3 = 16$ $16/50 = 0.32$

# %% [markdown]
# ### Question 13.2.8
# Write a Python program that calculates the probabilities of getting different sums of points (from 3 to 18)
# when you roll three dice. What sum has the highest probability?
# Hint: initialize a list of counts, all set to 0, then generate all possible combinations of points on three dice
# and for each combination increment the appropriate count.<br>
# ### Answer
# highest probability is 10 or maybe 11

# %%
from collections import Counter
total = 6**3
counts = Counter()
for a in range(1,7):
    for b in range(1,7):
        for c in range(1,7):
            counts[a+b+c] += 1

print("sum\tcount\tprob")
for s in range(3,19):
    print(f"{s}\t{counts[s]}\t{counts[s]/total:.6f}")

# Most likely sum:
max_sum = max(range(3,19), key=lambda s: counts[s])
print("Most likely sum:", max_sum, "with prob", counts[max_sum]/total)
# Out:
# sum	count	prob
# 3	1	0.004630
# 4	3	0.013889
# 5	6	0.027778
# 6	10	0.046296
# 7	15	0.069444
# 8	21	0.097222
# 9	25	0.115741
# 10	27	0.125000
# 11	27	0.125000
# 12	25	0.115741
# 13	21	0.097222
# 14	15	0.069444
# 15	10	0.046296
# 16	6	0.027778
# 17	3	0.013889
# 18	1	0.004630
# Most likely sum: 10 with prob 0.125

# %% [markdown]
# ### Question 13.3.1
# What is the probability of getting a “four of a kind” poker hand (four cards of the same rank plus any fifth
# card)?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# Number of favorable hands = choose the rank for the four (13) × choose the fifth card from remaining 48
# $13 x 48 = 624$ total 5 cards hands $C(52,5) = 2,598,960$ $p = 623/2,598,960 = 0.024%$

# %% [markdown]
# ### Question 13.3.4
# A bag has 3 red marbles and 5 blue marbles. If you randomly pull out 4 marbles, what is the probability of
# getting two red ones and two blue ones?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# favorable: $C(3,2) x C(5,2) = 3 x 10 = 30$ Total: $C(8,4) = 70$
# $p = 30/70 = 0.428571$

# %% [markdown]
# ### Question 13.3.5
# You draw cards from a deck of 52 cards until you get two cards of the same rank. What is the probability
# that you’ll end up with no more than three cards?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# a pair on second card $3/51 = 1/17$ after two prob. $48/51$ then third matches of first two would be prob. $6/50$ total $p = 3/51 + 48/51 x 6/50 = 17.176%$

# %% [markdown]
# ### Question 13.3.8
# What is the probability that a random Blackjack hand of 3 cards is worth 21 points? In Blackjack, each
# number card 2 through 10 counts at face value; any ace counts as 1 or 11, your choice; any other “picture”
# card (jack, queen, or king) counts as 10.
# Show your calculations and explain your reasoning.<br>
# ### Answer
# counting all 3 card combinations $2012/22100 = 9.104%$

# %% [markdown]
# ### Question 13.4.1
# What is the probability of rolling 3 on a die three times in a row?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# $(1/6)^3 = 1/216 = 0.00462962963$

# %% [markdown]
# ### Question 13.4.2
# In Scrabble™ there are 98 tiles with letters written on them. There are 2 Bs, 9 As, and 6 Ts. If you pull three
# tiles randomly out of the box, each time returning the tile to the box, what is the probability of getting B,
# A, T, in that order?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# $p(B)=2/98 p(A)=9/98 p(T)=6/98$ its split because of replacement
# $p = 2/98 x 9/98 x 6/98 = 0.0001147481$

# %% [markdown]
# ### Question 13.4.3
# What is the probability of rolling a die 3 times and never getting a 6?
# What is the probability of getting a 6 at least once?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# never getting a 6 $(5/6)^3 = 0.5787037$
# getting a least one 6 $1-(5/6)^3 = 0.4212963$

# %% [markdown]
# ### Question 13.4.9
# In the Tri-State Megabucks lottery you choose six numbers out of 42 numbers. If your numbers match the
# six drawn by the computer, you hit the jackpot. The computer also draws a seventh “bonus” number. If
# you didn’t hit the jackpot but your six numbers match any six numbers out of seven drawn by the
# computer (including the bonus number), you get a consolation prize of 10,000. There are other prizes,
# but they are relatively small.
# You decide to play only if your average win (probability of jackpot times the size of jackpot plus probability
# of bonus times the size of bonus) exceeds the ticket cost. If a ticket costs 1.00, what jackpot size makes
# it worth playing for you?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# jackpot prob.: $1/(42/6) = 1.906292 x 10^-7$
# prob. 6 are a subset of the 7 drawn: $36/(42/7)$ which excluding the jackpot = 1.1437752

# %% [markdown]
# ### Question 13.5.2
# Suppose you have a Python function random_letter() that returns a random letter of the alphabet
# (with approximately equal probabilities for all 26 letters). What is the probability that
# random_letter() will return three vowels (any of the letters ‘A’, ‘E’, ‘I’, ‘O’, ‘U’) in a row?
# Show your calculations and explain your reasoning.<br>
# ### Answer
# $p = (5/26)^3 = 0.7112%$

# %% [markdown]
# ### Question 13.5.3
# Write a Python function random_letter() as described in Question 2. Run it three times to see if you
# get three vowels in a row. Repeat 100,000 times. count how many times you got three vowels in a row,
# and estimate the probability of such an event.
# Compare your result to the theoretical probability that you obtained in Question 13.5.2.<br>
# ### Answer
# Simulation result (100,000 trials): 728 successes, Theoretical probability = 0.00711197086936732

# %%
import random

def random_letter():
    return random.choice("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

trials = 100_000
count = 0
for _ in range(trials):
    a,b,c = random_letter(), random_letter(), random_letter()
    if a in "AEIOU" and b in "AEIOU" and c in "AEIOU":
        count += 1

estimate = count/trials
print(count, trials, estimate, (5/26)**3)
# Out:
# 720 100000 0.0072 0.00711197086936732

# %% [markdown]
# ### Question 13.5.5
# Using the theoretical approach described in this section, write a program that prints out the probabilities
# that at least two people in a group of n have the same birthday, for n = 1 through 50, without using big
# integers. This program is just a few lines of code. The output should look like this:
# 1: 0.000
# 2: 0.003
# 3: 0.008
# ...
# 48: 0.961
# 49: 0.966
# 50: 0.970
# Watch out for “OBOBs” (off-by-one bugs), as we call the bugs that happen when a loop in your program
# runs one too few or one too many times. Determine from the printout the value of n at which the
# probability becomes greater than 0.5.<br>
# ### Answer

# %%
def shared_birthday_probs(max_n=50):
    probs = []
    prod = 1.0
    for n in range(1, max_n+1):
        if n==1:
            prod = 1.0
        else:
            prod *= (365 - (n-1))/365.0
        probs.append((n, 1 - prod))
    return probs

for n,p in shared_birthday_probs(50):
    print(f"{n}: {p:.3f}")
# Out:
# 1: 0.000
# 2: 0.003
# 3: 0.008
# 4: 0.016
# 5: 0.027
# 6: 0.040
# 7: 0.056
# 8: 0.074
# 9: 0.095
# 10: 0.117
# 11: 0.141
# 12: 0.167
# 13: 0.194
# 14: 0.223
# 15: 0.253
# 16: 0.284
# 17: 0.315
# 18: 0.347
# 19: 0.379
# 20: 0.411
# 21: 0.444
# 22: 0.476
# 23: 0.507
# 24: 0.538
# 25: 0.569
# 26: 0.598
# 27: 0.627
# 28: 0.654
# 29: 0.681
# 30: 0.706
# 31: 0.730
# 32: 0.753
# 33: 0.775
# 34: 0.795
# 35: 0.814
# 36: 0.832
# 37: 0.849
# 38: 0.864
# 39: 0.878
# 40: 0.891
# 41: 0.903
# 42: 0.914
# 43: 0.924
# 44: 0.933
# 45: 0.941
# 46: 0.948
# 47: 0.955
# 48: 0.961
# 49: 0.966
# 50: 0.970

# %% [markdown]
# ### Question 13.5.6
# Write a program that implements a Monte Carlo simulation for birthdays. Write a function that generates
# a list of n random birthdays (numbers from 1 to 365) and returns true if all the numbers in the list are
# different.
# Call this function a sufficient number of times to estimate the probability that at least two people out of
# n have the same birthday.
# Compare your result with the theoretical result obtained in Question 5. 6
# Hint: One way to find out whether generated numbers have duplicates is to allocate 365 counts and
# increment the appropriate count for each random number, then check whether any count is greater than
# 1
# ### Answer

# %%
import random

def all_unique_birthdays(n):
    seen = set()
    for _ in range(n):
        d = random.randint(1,365)
        if d in seen:
            return False
        seen.add(d)
    return True

def estimate_shared_prob(n, trials=10000):
    count_shared = 0
    for _ in range(trials):
        if not all_unique_birthdays(n):
            count_shared += 1
    return count_shared / trials

# Example: estimate for n = 23
print(estimate_shared_prob(23, trials=20000))
# Out:
# 0.5101
